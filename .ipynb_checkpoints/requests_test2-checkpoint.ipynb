# %% [markdown]
# [张亚楠](http://www.zhidaow.com/post/python-requests-install-and-brief-introduction)

# %%
import requests

# %%
r = requests.get('http://www.zhidaow.com')  # 发送请求
r.status_code  # 获取网页状态码
# Out:
# 200

# %%
r.headers  # 获取响应头内容。
# Out:
# {'x-cache-key': '2e87fe6641db7df5d4bbc68ec8e987a3-page', 'x-template-path': 'index+tags+category.jade', 'x-site-id': 'dropbox-9476296-\xe5\xbc\xa0\xe4\xba\x9a\xe6\xa5\xa0\xe7\x9a\x84\xe8\x87\xaa\xe8\xa8\x80\xe8\x87\xaa\xe8\xaf\xad', 'x-render-time': '0.00467920303345', 'x-host': '38.68.14.58', 'content-encoding': 'gzip', 'transfer-encoding': 'chunked', 'set-cookie': 'template_path=index+tags+category.jade; Path=/', 'x-route': 'render_custom_template', 'vary': 'Accept-Encoding', 'x-sentry-id': 'None', 'x-site-date': '2015-09-30 03:42:02.663000', 'server': 'Tengine/2.0.3', 'connection': 'keep-alive', 'cache-control': 'max-age=120', 'date': 'Sun, 11 Oct 2015 13:32:22 GMT', 'x-cached': 'yes', 'content-type': 'text/html', 'x-utc-offset': '8.0'}

# %%
r.headers['content-type']  # 返回头部信息
# Out:
# 'text/html'

# %%
r.encoding  # 编码信息
# Out:
# 'ISO-8859-1'

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='template_path', value='index+tags+category.jade', port=None, port_specified=False, domain='www.zhidaow.com', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
# r.content #内容部分（PS，由于编码问题，建议这里使用r.content）

# %% [markdown]
# - 在URL中传递参数

# %%
payload = {'wd': '张亚楠', 'rn': '100'}
r = requests.get('http://www.zhidaow.com', params=payload)
r.url
# Out:
# u'http://www.zhidaow.com/?rn=100&wd=%E5%BC%A0%E4%BA%9A%E6%A5%A0'

# %% [markdown]
# - 解析json

# %%
r = requests.get('http://ip.taobao.com/service/getIpInfo.php?ip=122.88.60.28')

# %%
print r.json()['data']
# Out:
# {u'ip': u'122.88.60.28', u'city': u'\u5357\u4eac\u5e02', u'area_id': u'300000', u'region_id': u'320000', u'area': u'\u534e\u4e1c', u'city_id': u'320100', u'country': u'\u4e2d\u56fd', u'region': u'\u6c5f\u82cf\u7701', u'isp': u'\u94c1\u901a', u'country_id': u'CN', u'county': u'', u'isp_id': u'100020', u'county_id': u'-1'}

# %%
print r.json()['data']['region']
# Out:
# 江苏省

# %% [markdown]
# - 代理访问

# %%
import requests

proxies = {
  "http": "http://222.59.161.12:8118",
  "https": "http://119.190.10.157:9000",
} 
# 若代理需要账户和密码，则需这样： proxies = {"http": "http://user:pass@10.10.1.10:3128/"}

# %%
r = requests.get("http://www.zhidaow.com", proxies=proxies)

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# - 请求头内容

# %%
r.request.headers  # r.request.headers来获取请求头内容
# Out:
# {'Connection': 'keep-alive', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'User-Agent': 'python-requests/2.7.0 CPython/2.7.10 Windows/8'}

# %% [markdown]
#  - 自定义请求头部

# %%
r = requests.get('http://www.zhidaow.com')
r.request.headers['User-Agent']
# Out:
# 'python-requests/2.7.0 CPython/2.7.10 Windows/8'

# %%
headers = {'User-Agent': 'alexkh'}
r = requests.get('http://www.zhidaow.com', headers=headers)  # headers参数
r.request.headers['User-Agent']
# Out:
# 'alexkh'

# %% [markdown]
# - 登录网站

# %%
#coding=utf8
import requests

login_url = 'http://www.example.com/login'
user_url = 'http://www.example.com/user/alexkh/'
s = requests.Session()  # 会话形式访问，保存cookie
data = {  # 登陆信息
    'username': 'alexkh',
    'password': 'size_the_day',
}
s.post(login_url, data=data)  # post数据
r = s.get(user_url)  # 接着访问用户页
print r.content

# %%
#coding=utf8
import requests

login_url = 'https://passport.csdn.net/account/login?from=http://my.csdn.net/my/mycsdn'
user_url = 'http://www.example.com/user/alexkh/'
s = requests.Session()  # 会话形式访问，保存cookie
data = {  # 登陆信息
    'username': 'caiguoxiong0101@163.com',
    'password': 'C@i224dd',
}
s.post(login_url, data=data)  # post数据
r = s.get(user_url)  # 接着访问用户页
print r.content

# %% [markdown]
# - python批量查询百度收录

# %%
# coding=utf-8

import requests
from bs4 import BeautifulSoup as bs
import re

headers = {  
    'User-Agent': 'Mozilla/4.0+(compatible;+MSIE+8.0;+Windows+NT+5.1;+Trident/4.0;+GTB7.1;+.NET+CLR+2.0.50727)'
}  # 设置UA模拟用户，还可设置多个UA提高搜索成功率

def baidu_url(word): # 构建百度搜索URL；因为是查收录，所以只显示了前10个搜索结果，还可以通过rn参数来调整搜索结果的数量
    '''
    get baidu search url
    '''
    return 'http://www.baidu.com/s?wd=%s' % word

# %%
url = baidu_url(u'蔡国雄')

# %%
def baidu_cont(url):  # 获取百度搜索结果页内容
    r = requests.get(url, headers=headers)
    return r.content

# %%
print baidu_cont(url)
# Out:
# <!DOCTYPE html><!--STATUS OK--><html><head><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta http-equiv="content-type" content="text/html;charset=utf-8"><meta content="always" name="referrer"><meta name="theme-color" content="#2932e1"><link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" /><link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu.svg"><link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="百度搜索" /><title>蔡国雄_百度搜索</title><style data-for="result"  id="css_newi_result">body{color:#333;background:#fff;padding:6px 0 0;margin:0;position:relative;min-width:900px}body,th,td,.p1,.p2{font-family:arial}p,form,ol,ul,li,dl,dt,dd,h3{margin:0;padding:0;list-style:none}input{padding-top:0;padding-bottom:0;-moz-box-sizing:border-box;-webkit-box-sizing:border-box;box-sizing:border-box}table,img{border:0}td{font-size:9pt;line-height:18px}em{font-style:normal;color:#c00}a em{text-decoration:underline}cite{fo
# ...

# %%
def serp_links(word):  #获取百度搜索结果的最终URL
    '''
    get baidu serp links with the word
    '''
    b_url = baidu_url(word)
    soup = bs(baidu_cont(b_url))
    b_tags = soup.find_all('h3', {'class': 't'})  # 获取URL的特征值是通过class="t"
    b_links = [tag.a['href'] for tag in b_tags]
    real_links = []
    for link in b_links:  # 使用requests库获取了最终URL，而不是快照URL
        try:
            r = requests.get(link, headers=headers, timeout=120)
        except Exception as e:
            real_links.append('page404')
        else:
            real_links.append(r.url)
    return real_links

# %%
result_urls = serp_links(u'蔡国雄')

# %%
result_urls
# Out:
# [u'http://baike.baidu.com/link?url=6a8YVdi1xH_lk_-fGxIOjOx-Rzo6DxPoqnREt0cJ7FMH_R144kTvquMKJ8vmoH7E_kf3XwrST1it7LtyEJ_Xyq',
#  u'http://zhengwu.beijing.gov.cn/sld/szxld/fzx/t924154.htm',
#  u'http://guangfu.bjx.com.cn/special/?id=594053',
#  u'http://www.cpnn.com.cn/zdyw/201503/t20150306_786326.html',
#  u'http://xueshu.baidu.com/s?wd=%E8%94%A1%E5%9B%BD%E9%9B%84&tn=SE_baiduxueshu_c1gjeupa&ie=utf-8&sc_hit=1',
#  u'http://image.baidu.com/search/index?tn=baiduimage&ct=201326592&lm=-1&cl=2&ie=gbk&word=%B2%CC%B9%FA%D0%DB&fr=ala&ori_query=%E8%94%A1%E5%9B%BD%E9%9B%84&ala=0&alatpl=sp&pos=0',
#  u'http://news.163.com/special/lianghuicaiguoxiong/',
#  u'http://www.wokeji.com/kbjh/zxbd_10031/201503/t20150303_982160.shtml',
#  u'http://www.chinadaily.com.cn/hqcj/zxqxb/2015-03-09/content_13342343.html',
#  u'http://www.gzbsx.com/News_show.asp?type=zt&id=3477']

# %% [markdown]
# - 带参数的请求

# %%
requests.get('http://www.dict.baidu.com/s', params={'wd': 'python'})    #GET参数实例
# Out:
# <Response [200]>

# %%
requests.post('http://www.itwhy.org/wp-comments-post.php', data={'comment': '测试POST'})    #POST参数实例
# Out:
# <Response [403]>

# %% [markdown]
# - POST发送JSON数据：

# %%
import json
r = requests.post('https://api.github.com/some/endpoint', data=json.dumps({'some': 'data'}))
r.json()
# Out:
# {u'documentation_url': u'https://developer.github.com/v3',
#  u'message': u'Not Found'}

# %% [markdown]
# - 定制header：

# %%
import json
 
data = {'some': 'data'}
headers = {'content-type': 'application/json',
           'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:22.0) Gecko/20100101 Firefox/22.0'}
 
r = requests.post('https://api.github.com/some/endpoint', data=data, headers=headers)
r.text
# Out:
# u'{\n  "message": "Not Found",\n  "documentation_url": "https://developer.github.com/v3"\n}\n'

# %%
r = requests.get('http://www.itwhy.org')
# print r.text, '\n{}\n'.format('*'*79), r.encoding

# %%
r.encoding = 'utf-8'  # 让 r.text 使用自定义的编码进行解码
# print r.text, '\n{}\n'.format('*'*79), r.encoding

# %% [markdown]
#     r.status_code #响应状态码
#     r.raw #返回原始响应体，也就是 urllib 的 response 对象，使用 r.raw.read() 读取
#     r.content #字节方式的响应体，会自动为你解码 gzip 和 deflate 压缩
#     r.text #字符串方式的响应体，会自动根据响应头部的字符编码进行解码
#     r.headers #以字典对象存储服务器响应头，但是这个字典比较特殊，字典键不区分大小写，若键不存在则返回None
#     #*特殊方法*#
#     r.json() #Requests中内置的JSON解码器
#     r.raise_for_status() #失败请求(非200响应)抛出异常

# %% [markdown]
# ### 基本身份认证

# %%
import requests
from requests.auth import HTTPBasicAuth

r = requests.get('https://httpbin.org/hidden-basic-auth/user/passwd', auth=HTTPBasicAuth('user', 'passwd'))
# r = requests.get('https://httpbin.org/hidden-basic-auth/user/passwd', auth=('user', 'passwd'))    # 简写
print r.json()
# Out:
# {u'authenticated': True, u'user': u'user'}

# %% [markdown]
# - 另一种非常流行的HTTP身份认证形式是摘要式身份认证，Requests对它的支持也是开箱即可用的:
# > requests.get(URL, auth=HTTPDigestAuth('user', 'pass'))

# %% [markdown]
# ### 六、Cookies与会话对象

# %%
r = requests.get('http://www.baidu.com/')

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='BAIDUID', value='B24AFE907B0D2BD2C8FD440BA2807460:FG=1', port=None, port_specified=False, domain='.baidu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=3592055222L, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='BIDUPSID', value='B24AFE907B0D2BD2C8FD440BA2807460', port=None, port_specified=False, domain='.baidu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=3592055222L, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='H_PS_PSSID', value='10298_1440_17464_12657_17287_14431_17245_17295_17001_17471_17072_15390_17347_11851_17351_17051', port=None, port_specified=False, domain='.baidu.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url
# ...

# %%
dict(r.cookies)
# Out:
# {'BAIDUID': 'B24AFE907B0D2BD2C8FD440BA2807460:FG=1',
#  'BDSVRTM': '0',
#  'BD_HOME': '0',
#  'BIDUPSID': 'B24AFE907B0D2BD2C8FD440BA2807460',
#  'H_PS_PSSID': '10298_1440_17464_12657_17287_14431_17245_17295_17001_17471_17072_15390_17347_11851_17351_17051',
#  'PSTM': '1444571574'}

# %%
r.cookies['BAIDUID']
# Out:
# 'B24AFE907B0D2BD2C8FD440BA2807460:FG=1'

# %% [markdown]
# - 发送你的cookies到服务器，可以使用 cookies 参数

# %%
url = 'http://httpbin.org/cookies'
cookies = {'testCookies_1': 'Hello_Python3', 'testCookies_2': 'Hello_Requests'}
# 在Cookie Version 0中规定空格、方括号、圆括号、等于号、逗号、双引号、斜杠、问号、@，冒号，分号等特殊符号都不能作为Cookie的内容。
r = requests.get(url, cookies=cookies)
print r.json()
# Out:
# {u'cookies': {u'testCookies_1': u'Hello_Python3', u'testCookies_2': u'Hello_Requests'}}

# %%
#encoding:utf-8  
import urllib2,cookielib  
import re  
  
# 在网页登陆成功后的cookies字符串  
cookie = 'uuid_tt_dd=8118493737293334706_20150725; CloudGuest=5GTSQYvkdYhX2Duc9bdGBRq++E5X/EYSKS+Q2EfQQN/0F+Zn5aqOvs991sGq4f0DZNMV32yo/lg9sFsaPariaVmMw/Z/c6h446sO5CsWOOaMCU5qhqjMMs8V9JoCOTrPSwXcZxIRn/erURpUe59b7rJ8lDcTwFMx4aWC4tIoqtvGyENmufhqmkdu59UtoGtp; bdshare_firstime=1439700186480; lzstat_uv=26874684582620892805|3520372@3479011; __utma=17226283.1000362730.1437829406.1440428220.1444572403.2; __utmb=17226283.4.10.1444572403; __utmc=17226283; __utmz=17226283.1444572403.2.2.utmcsr=baidu|utmccn=(organic)|utmcmd=organic; _gat=1; UserName=caiguoxiong0101; UserInfo=PSg6kq7WMl91r8mTQgbOnUmTRElE323xcsqZFtWOSwpf%2BH8ZuAmHlg7o3PrxsmBpERfTm3Id7RAh4RXstx%2BzEwM%2B9Et5Alx6PjmfX65Nzb7NHfmEVxi65uGePFHNeo8b6ZMdPCiUdCJrYTvnlRSXDA%3D%3D; UserNick=%E6%B8%A9%E6%9F%94%E4%B8%80cai%E5%88%80; AU=CDF; UD=%E5%B7%B2%E7%9F%A5%E8%B6%8A%E5%A4%9A%EF%BC%8C%E6%9C%AA%E7%9F%A5%E8%B6%8A%E5%A4%9A%EF%BC%81; UN=caiguoxiong0101; UE="caiguoxiong0101@163.com"; access-token=b1f87e7e-dbe3-4a27-8493-f691b99c3dc9; _ga=GA1.2.1000362730.1437829406; dc_tos=nw28zh; dc_session_id=1444574717212'
req = urllib2.Request("https://passport.csdn.net/account/login?from=http%3A%2F%2Fmy.csdn.net%2F%2Fmy%2Faccount%2Fchangepwd%3Fref%3Dtoolbar")  
  
req.add_header('Cookie', cookie)  
req.add_header("Content-Encoding","gzip")  
req.add_header("User-Agent",r"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:26.0) Gecko/20100101 Firefox/26.0")  
  
content = urllib2.urlopen(req).read()

# %%
print content
# Out:
# <html>
#   <head>
#     <meta charset="utf-8" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <meta property="qc:admins" content="24530273213633466654" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#     <title>帐号登录</title>
#
#
#     <link type="text/css" rel="stylesheet" href="/css/bootstrap.css;jsessionid=952DB7ED3FA6177B82BD1F76739D9C66.tomcat3" />
#     <link type="text/css" rel="stylesheet" href="/css/login.css;jsessionid=952DB7ED3FA6177B82BD1F76739D9C66.tomcat3" />
#     <script src="/js/apps/ga.js;jsessionid=952DB7ED3FA6177B82BD1F76739D9C66.tomcat3"></script>
#     <!--[if lt IE 9]>
#     <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#     <script src="https://oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"></script>
#     <![endif]-->
#   </head>
#   <body>
#   	<script type="text/javascript">
#   		var protocol = window.location.protocol;
# ...

# %%
#coding=utf8
import requests

login_url = 'https://passport.csdn.net/account/login?ref=toolbar'
s = requests.Session()  # 会话形式访问，保存cookie
headers = {'content-type': 'application/json',
           'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:22.0) Gecko/20100101 Firefox/22.0'}
data = {  # 登陆信息
    'username': 'caiguoxiong01
    01@163.com',
    'password': 'C@i224'
}
s.post(login_url, data=data, headers=headers)  # post数据
# Out:
# <Response [200]>

# %%
r = requests.get('http://my.csdn.net/my/mycsdn')
r.content
# Out:
# '<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body bgcolor="white">\r\n<center><h1>403 Forbidden</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
print r.content
# Out:
# <html>
#   <head>
#     <meta charset="utf-8" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <meta property="qc:admins" content="24530273213633466654" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#     <title>帐号登录</title>
#
#
#     <link type="text/css" rel="stylesheet" href="/css/bootstrap.css;jsessionid=720C8BE0C420186A9FE0B576509DF382.tomcat4" />
#     <link type="text/css" rel="stylesheet" href="/css/login.css;jsessionid=720C8BE0C420186A9FE0B576509DF382.tomcat4" />
#     <script src="/js/apps/ga.js;jsessionid=720C8BE0C420186A9FE0B576509DF382.tomcat4"></script>
#     <!--[if lt IE 9]>
#     <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#     <script src="https://oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"></script>
#     <![endif]-->
#   </head>
#   <body>
#   	<script type="text/javascript">
#   		var protocol = window.location.protocol;
# ...

# %%
s = requests.session()
headers = {'content-type': 'application/json',
           'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:22.0) Gecko/20100101 Firefox/22.0'}
login_data = {'email': 'caiguoxiong0101@163.com',
              'password': 'cgx597009276', 
              'remember_me': 'true', 
              '_xsrf' : '35efacd4d92a4468e7eb37156263f3b1'}
# post 数据实现登录
s.post("http://www.zhihu.com/login/email", data=login_data, headers=headers)
# 验证是否登陆成功，抓取'知乎'首页看看内容
# Out:
# <Response [200]>

# %%
r = s.get('http://www.zhihu.com')
print r.content
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
# <meta charset="utf-8">
# <meta name="apple-itunes-app" content="app-id=432274380">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="renderer" content="webkit" />
# <meta name="description" content="一个真实的网络问答社区，帮助你寻找答案，分享知识。"/>
# <meta name="viewport" content="user-scalable=no, width=device-width, initial-scale=1.0, maximum-scale=1.0"/>
# <title>知乎 - 与世界分享你的知识、经验和见解</title>
# <link rel="apple-touch-icon-precomposed" href="http://static.zhihu.com/static/img/ios/zhihu(57px).png" />
# <link rel="apple-touch-icon-precomposed" href="http://static.zhihu.com/static/img/ios/zhihu(72px).png" sizes="72x72" />
# <link rel="apple-touch-icon-precomposed" href="http://static.zhihu.com/static/img/ios/zhihu(76px).png" sizes="76x76" />
# <link rel="apple-touch-icon-precomposed" href="http://static.zhihu.com/static/img/ios/zhihu(114px).png" sizes="114x114" />
# ...
